# %% [markdown]
# <a href="https://colab.research.google.com/github/Geysa-Ribeiro/machineLearning_2026/blob/main/aula0704_amt4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pipeline | Anomalias e Normalização [Fase 1 - credit_data]

# %% [markdown]
# ##Importa dados do Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##Bibliotecas do Python

# %%
# !pip -q install plotly
# !pip -q install yellowbrick

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as pit
import plotly.express as px

# %% [markdown]
# ##Importa DataFrame [base_credit] - Descrição da Base

# %%
base_credit = pd.read_csv('/content/drive/MyDrive/AM_t4/credit_data.csv')

# %%
base_credit
# Out:
#       clientid        income        age         loan  default
# 0            1  66155.925095  59.017015  8106.532131        0
# 1            2  34415.153966  48.117153  6564.745018        0
# 2            3  57317.170063  63.108049  8020.953296        0
# 3            4  42709.534201  45.751972  6103.642260        0
# 4            5  66952.688845  18.584336  8770.099235        1
# ...        ...           ...        ...          ...      ...
# 1995      1996  59221.044874  48.518179  1926.729397        0
# 1996      1997  69516.127573  23.162104  3503.176156        0
# 1997      1998  44311.449262  28.017167  5522.786693        1
# 1998      1999  43756.056605  63.971796  1622.722598        0
# 1999      2000  69436.579552  56.152617  7378.833599        0
#
# [2000 rows x 5 columns]
